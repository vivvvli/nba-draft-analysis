# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment
import pandas as pd

# %%
def append_college_stats(rows):
    player_stats = []
    for i in range(len(rows)):
        player = [td.getText() for td in rows[i].findAll('td')]
        if player == []:
            continue
        td_list = rows[i].findAll('td')
    for i in range(len(rows)):
        player = [td.getText() for td in rows[i].findAll('td')]
        if player == []:
            continue
        td_list = rows[i].findAll('td')
        for td in td_list:  
            if td['data-stat'] == "player":
                button = td.findAll('a')
                if button != []:
                    link = button[0]['href']
                    player_url = "https://www.basketball-reference.com{}".format(link)
                    player_html = urlopen(player_url)
                    player_soup = BeautifulSoup(player_html)
                    college_stats = player_soup.findAll(id="all_all_college_stats")
                    player_height_temp = player_soup.findAll("span",{'itemprop': 'height'})[0].text
                    player_height = int(player_height_temp.split('-')[0])+(int(player_height_temp.split('-')[1])/12)
                    player_weight = player_soup.findAll("span",{'itemprop':'weight'})[0].text
                    birth_date = player_soup.findAll("div",{"itemtype":"https://schema.org/Person"})[0].findAll("span",{"id":"necro-birth"})[0].text.replace('\n','').strip()
                    birth_place = player_soup.findAll("div",{"itemtype":"https://schema.org/Person"})[0].find("span",{"itemprop":"birthPlace"}).a.text                    
                    for each in player_soup.findAll('p'):
                        if 'Position:' in each.text:
                            player_position = each.text.replace('\n','').strip().split(' ')[4]
                    if college_stats != []:
                        for comments in college_stats[0].findAll(text=lambda text:isinstance(text, Comment)):
                            x = comments.extract()
                            comment_soup = BeautifulSoup(x , 'lxml')
                            tfoot = comment_soup.findAll('tfoot')
                            td = tfoot[0].findAll('td')
                            for i in range(2, len(td)):
                                player.append(td[i].getText())
                            player.append(player_height)
                            player.append(player_weight)
                            player.append(birth_date)
                            player.append(birth_place)
                            player.append(player_position)
        player_stats.append(player)
        print('PROCESSING PLAYER {}'.format(player_url))
    return player_stats

# %%
# Defining range of draft classes
start_year = 2007
end_year = 2019
college_headers = ['college_G',
                   'college_MP',
                   'college_FG',
                    'college_FGA',
                    'college_3P',
                    'college_3PA',
                    'college_FT',
                    'college_FTA',
                    'college_ORB',
                    'college_TRB',
                    'college_AST',
                    'college_STL',
                    'college_BLK',
                    'college_TOV',
                    'college_PF',
                    'college_PTS',
                    'college_FG%',
                    'college_3P%',
                    'college_FT%',
                    'college_MP',
                    'college_PTS%',
                    'college_TRB',
                    'college_AST',
                   'height',
                   'weight',
                   'date_of_birth',
                   'place_of_birth',
                   'position'
                  ]

# Initialize .csv writer
writer = pd.ExcelWriter('nba_draft.xlsx', engine='xlsxwriter')

# Push data to .csv file (1 sheet per draft class)
for i in range(start_year, end_year + 1):
    url = "https://www.basketball-reference.com/draft/NBA_{}.html".format(i)
    html = urlopen(url)
    soup = BeautifulSoup(html)
    rows = soup.findAll('tr', limit=2)
    headers = [th.getText() for th in rows[1].findAll('th')]
    headers = headers[1:]
    headers = headers + college_headers    
    rows = soup.findAll('tr')[2:]
    player_stats = append_college_stats(rows)
    stats = pd.DataFrame(player_stats, columns = headers)
    stats = stats.dropna()
    data = stats.head(60)
    stats.to_excel(writer, sheet_name='draft_data_{}'.format(i), index = False)
    
# Save .csv data
writer.save()
# Out:
# PROCESSING PLAYER https://www.basketball-reference.com/players/o/odengr01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/d/duranke01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/h/horfoal01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/c/conlemi01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/g/greenje02.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/j/jianlyi01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/breweco01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/w/wrighbr03.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/n/noahjo01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/h/hawessp01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/l/lawac01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/y/youngth01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/w/wrighju01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/t/thornal01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/stuckro01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/y/youngni01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/w/willise01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/belinma01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/c/crittja01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/smithja02.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/c/cookda02.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/d/dudleja01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/c/chandwi01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/f/fernaru01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/a/almonmo01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/brookaa01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/a/afflaar01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/splitti01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/t/tuckeal02.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/k/koponpe01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/l/landrca01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/p/pruitga01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/w/willima04.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/f/fazekni01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/d/davisgl01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/d/davidje01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/m/mcrobjo01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/f/fesenky01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/baracst01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/y/yuesu01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/r/richach01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/byarsde01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/byarsde01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/byarsde01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/b/byarsde01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/l/lasmest01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/m/mcguido01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/g/gasolma01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/g/grayaa01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/seibure01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/c/curryja01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/g/greenta01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/n/nichode01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/n/newlebr01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/n/newlebr01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/sessira01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/sessira01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/p/printgi01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/s/strawdj01.html
# PROCESSING PLAYER https://www.basketball-reference.com/players/r/rakovmi01.html
